# %%
# %matplotlib inline
import pandas as pd

# %%
cast = pd.read_csv('F://AIX Docs//Data science//Python//datasets//cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
cast.title.value_counts().sum()
# Out:
# 3611212

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
cast.sort_values('year').head(2)['title']
# Out:
# 2514470    Miss Jerry
# 555929     Miss Jerry
# Name: title, dtype: object

# %%
cast.sort_values('year').head(2)
# Out:
#               title  year             name     type  \
# 2514470  Miss Jerry  1894  Blanche Bayliss  actress
# 555929   Miss Jerry  1894   Chauncey Depew    actor
#
#                                                  character   n
# 2514470               Miss Geraldine Holbrook (Miss Jerry) NaN
# 555929   Himself - the Director of the New York Central... NaN

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
len(cast[cast.title=='Hamlet'])
# Out:
# 313

# %%
cast[cast.title=='Hamlet']
# Out:
#           title  year                  name     type  \
# 1615     Hamlet  1996            Riz Abbasi    actor
# 7438     Hamlet  1921      Fritz Achterberg    actor
# 11242    Hamlet  2009          Hayden Adams    actor
# 11243    Hamlet  2009          Hayden Adams    actor
# 13907    Hamlet  1913           Eric Adeney    actor
# 16079    Hamlet  2000         Casey Affleck    actor
# 32916    Hamlet  1964        Hugh Alexander    actor
# 32917    Hamlet  1964        Hugh Alexander    actor
# 32918    Hamlet  1964        Hugh Alexander    actor
# 52487    Hamlet  1913        Richard Andean    actor
# 62270    Hamlet  1990      Christien Anholt    actor
# 74921    Hamlet  1969              Ben Aris    actor
# 80019    Hamlet  2015    Thomas (II) Arnold    actor
# 92106    Hamlet  1996  Richard Attenborough    actor
# 100256   Hamlet  1948          Felix Aylmer    actor
# 132982   Hamlet  1913           J.H. Barnes    actor
# 140011   Hamlet  2000           Paul Bartel    actor
# ...

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(cast[cast.title=="North by Northwest"])
# Out:
# 112

# %%
cast[cast.title=="North by Northwest"]
# Out:
#                       title  year                  name     type  \
# 12151    North by Northwest  1959         Stanley Adams    actor
# 27852    North by Northwest  1959            Andy Albin    actor
# 54093    North by Northwest  1959          Don Anderson    actor
# 54307    North by Northwest  1959       Ernest Anderson    actor
# 92195    North by Northwest  1959     Malcolm Atterbury    actor
# 97833    North by Northwest  1959             Tol Avery    actor
# 109025   North by Northwest  1959            Sam Bagley    actor
# 114334   North by Northwest  1959           Frank Baker    actor
# 137656   North by Northwest  1959         Baynes Barron    actor
# 151717   North by Northwest  1959         Brandon Beach    actor
# 176030   North by Northwest  1959         John Beradino    actor
# 198496   North by Northwest  1959          Edward Binns    actor
# 222299   North by Northwest  1959       Stephen Bolster    actor
# ...

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
cast[cast.title=="Hamlet"].sort_values('year').head(1)['year']
# Out:
# 1545289    1910
# Name: year, dtype: int64

# %%
cast[cast.title=="Hamlet"].sort_values('year')
# Out:
#           title  year                       name     type           character  \
# 1545289  Hamlet  1910          Jean Mounet-Sully    actor              Hamlet
# 1233662  Hamlet  1911            Oscar Langkilde    actor             Horatio
# 2422953  Hamlet  1911           Einar Zangenberg    actor             Laertes
# 3015440  Hamlet  1911               Ella La Cour  actress            Gertrude
# 1592118  Hamlet  1911                 Alwin Neu?    actor              Hamlet
# 954648   Hamlet  1911                Aage Hertel    actor            Claudius
# 3369033  Hamlet  1911              Emilie Sannom  actress             Ophelia
# 720239   Hamlet  1913  Johnston Forbes-Robertson    actor              Hamlet
# 1839655  Hamlet  1913               Percy Rhodes    actor           The Ghost
# 1843850  Hamlet  1913           G. (II) Richards    actor            Bernardo
# 1853843  Hamlet  1913             Walter Ringham    actor            Claudius
# ...

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
cast[cast.title=="Treasure Island"].sort_values('year')
# Out:
#                    title  year                      name     type  \
# 830114   Treasure Island  1918            Charles Gorman    actor
# 840745   Treasure Island  1918                 Joe Grant    actor
# 909157   Treasure Island  1918              Edwin Harley    actor
# 3298306  Treasure Island  1918          Violet Radcliffe  actress
# 1715014  Treasure Island  1918                Lloyd Perl    actor
# 3553298  Treasure Island  1918        Eleanor Washington  actress
# 339256   Treasure Island  1918         Francis Carpenter    actor
# 1261579  Treasure Island  1918               Raymond Lee    actor
# 1291387  Treasure Island  1918              Elmo Lincoln    actor
# 1946119  Treasure Island  1918             Lewis Sargent    actor
# 2654214  Treasure Island  1918       Virginia Lee Corbin  actress
# 1417884  Treasure Island  1918           Herschel Mayall    actor
# 1473574  Treasure Island  1918           Buddy Messinger    actor
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(cast[cast.year==1950])
# Out:
# 22006

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(cast[cast.year==1960])
# Out:
# 18456

# %%
cast[cast.year==1960]
# Out:
#                                      title  year                      name  \
# 68                            De zaak M.P.  1960             Frans 't Hoen
# 115                    Thunder in Carolina  1960  2nd Marine Division Band
# 133                               Noi duri  1960              5 Asternovas
# 265             Sri Venkateswara Mahatmyam  1960        Subba Rao A.V. Jr.
# 268             Sri Venkateswara Mahatmyam  1960            Subba Rao A.V.
# 965                      Stublenskite lipi  1960         Dimitar Abadzhiev
# 1388                      Malak wa shaitan  1960              Rushdy Abaza
# 1495                 Sunrise at Campobello  1960            Abdullah Abbas
# 3299                 Arashi o yobu gakudan  1960                  T?ru Abe
# 3303                           Fuefukigawa  1960                  T?ru Abe
# 4198                              Kardakar  1960               K. Abesadze
# ...

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len(cast[(cast.year>=1950) & (cast.year<=1959)])
# Out:
# 210986

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
cast[cast.title=='Batman'].sort_values('year')['year'].unique()
# Out:
# array([1943, 1989], dtype=int64)

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
len(cast[cast.title=="Inception"])
# Out:
# 77

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast[cast.title=="Inception"]['n'].isnull().sum()
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
cast[cast.title=="Inception"]['n'].notnull().sum()
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[cast.title=="North by Northwest"].sort_values('n').dropna()
# Out:
#                       title  year                  name     type  \
# 840374   North by Northwest  1959            Cary Grant    actor
# 3361396  North by Northwest  1959       Eva Marie Saint  actress
# 1404704  North by Northwest  1959           James Mason    actor
# 3024085  North by Northwest  1959   Jessie Royce Landis  actress
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 2923056  North by Northwest  1959  Josephine Hutchinson  actress
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# 447893   North by Northwest  1959       Philip Coolidge    actor
# ...

# %%
cast[cast.title=="North by Northwest"].sort_values('n').dropna()['name']
# Out:
# 840374               Cary Grant
# 3361396         Eva Marie Saint
# 1404704             James Mason
# 3024085     Jessie Royce Landis
# 343701           Leo G. Carroll
# 2923056    Josephine Hutchinson
# 1634552             Philip Ober
# 1229083           Martin Landau
# 2357939           Adam Williams
# 1746383            Edward Platt
# 642085        Robert Ellenstein
# 2212083            Les Tremayne
# 447893          Philip Coolidge
# 1454363           Patrick McVey
# 198496             Edward Binns
# 1334726               Ken Lynch
# Name: name, dtype: object

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast.title=='Sleuth')&(cast.year==1972)].sort_values('n')
# Out:
#           title  year                name     type  \
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
# 1396572  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 2619278             Marguerite Wyke  5.0
# 1396572      Police Constable Higgs  6.0

# %%
cast[(cast.title=='Sleuth')&(cast.year==1972)].sort_values('n')['name']
# Out:
# 1644328      Laurence Olivier
# 314691          Michael Caine
# 360365         Alec Cawthorne
# 1412647    John (II) Matthews
# 2619278    Eve (III) Channing
# 1396572          Teddy Martin
# Name: name, dtype: object

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast.title=='Sleuth')&(cast.year==2007)].sort_values('n')
# Out:
#           title  year                 name     type          character    n
# 314692   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %%
cast[(cast.title=='Sleuth')&(cast.year==2007)].sort_values('n')['name']
# Out:
# 314692           Michael Caine
# 1246855               Jude Law
# 1741124          Harold Pinter
# 250297         Kenneth Branagh
# 360366     Alec (II) Cawthorne
# 2619277      Eve (II) Channing
# 3223502      Carmel O'Sullivan
# Name: name, dtype: object

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast.title=='Hamlet')&(cast.year==1921)]['character'].nunique()
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[(cast.title=='Hamlet')&(cast.year==1996)]
# Out:
#           title  year                    name     type  \
# 1615     Hamlet  1996              Riz Abbasi    actor
# 92106    Hamlet  1996    Richard Attenborough    actor
# 152349   Hamlet  1996     Simon Russell Beale    actor
# 206181   Hamlet  1996         David (V) Blair    actor
# 211111   Hamlet  1996           Brian Blessed    actor
# 241315   Hamlet  1996      Christopher Bowles    actor
# 250281   Hamlet  1996         Kenneth Branagh    actor
# 262368   Hamlet  1996          Richard Briers    actor
# 283598   Hamlet  1996          Michael Bryant    actor
# 307699   Hamlet  1996            Peter Bygott    actor
# 331657   Hamlet  1996       Kenneth W Caravan    actor
# 482982   Hamlet  1996           Billy Crystal    actor
# 500005   Hamlet  1996           Charles Daish    actor
# 555725   Hamlet  1996        G?rard Depardieu    actor
# 577284   Hamlet  1996          Reece Dinsdale    actor
# 582748   Hamlet  1996                Ken Dodd    actor
# ...

# %%
cast[(cast.title=='Hamlet')&(cast.year==1996)&(cast.name=='Kenneth Branagh')]
# Out:
#          title  year             name   type character    n
# 250281  Hamlet  1996  Kenneth Branagh  actor    Hamlet  5.0

# %%
len(cast[(cast.title=='Hamlet')&(cast.year==1996)&(cast.name=='Kenneth Branagh')])
# Out:
# 1

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[(cast.title=='Hamlet')]['character'].nunique()
# Out:
# 107

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
len(cast[cast.character=='Ophelia'])
# Out:
# 111

# %%
cast[cast.character=='Ophelia']['name'].nunique()
# Out:
# 109

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast.character=='The Dude']['name'].nunique()
# Out:
# 18

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast.character=='The Stranger']['name'].nunique()
# Out:
# 197

# %%
cast[cast.character=='The Stranger']['name'].unique()
# Out:
# array(['Hassan Mutlag Al-Maraiyeh', 'Vincent H. Alexander',
#        'Tony Anthony', 'Phil Arnold', 'Ryan Andrew Balas', 'Cristi Balea',
#        'Richard Baron', 'Nigel Barrett', 'Harry Basch', 'Arben Biba',
#        'Richard (XV) Bishop', 'Frank Borzage', 'Pinkas Braun',
#        'Gerard Butler', 'Nicholas Campbell', 'Nik Catello',
#        'Lyster Chambers', 'Michael V. Chastain', 'Chazz', 'Alan Christy',
#        'Jason (VII) Coleman', 'Hallam Cooley', 'Sharlto Copley',
#        'Ste Cork', 'Gino Corrado', 'Harp Corrigan', 'Walter Coy',
#        'Shawn Crosby', 'Jemo Dalipovic', 'Matt Danner', 'Helmut Dantine',
#        'Josh Davidson', 'William B. Davidson', 'Jim Davis',
#        'Ben (V) Dawson', 'Michael Dawu', 'Tim DeKay', 'Patrick Dempsey',
#        'Joe DeRita', 'Alex Diakun', 'Billy Drago', 'Tex Driscoll',
#        'Rainer D?sing', 'Eddie Eagle', 'Clint Eastwood',
#        'James L. Edwards', 'Sam Elliott', 'Alberto Esparza',
# ...

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast.name=='Sidney Poitier']['character'].unique()
# Out:
# array(['Gordon Ralfe', 'Manny Durrell', 'Walter Lee Younger',
#        'Dr. Matt Younger', 'Sgt. Eddie Towler', 'Rau-Ru',
#        'Gregory W. Miller', 'John Kane', 'Buck', 'Reverend Msimangu',
#        'Toller', 'Tommy Tyler', 'Jack Parks', 'Inman Jackson',
#        'Gates Watson', 'John Prentice', 'Virgil Tibbs', 'Clyde Williams',
#        'Homer Smith', 'Roy Parmenter', 'Dr. Luther Brooks', 'Eddie Cook',
#        'Porgy', 'Doctor', 'Robertson', 'Night Club Extra',
#        'Warren Stantin', 'Donald Crease', 'Kimani Wa Karanja',
#        'Ben Munceford', 'Noah Cullen', 'Simon of Cyrene',
#        'FBI Deputy Director Carter Preston', 'Aly Mansuh', 'Jason Higgs',
#        'Obam', 'Alan Newell', 'Shack Twala', 'Mark Thackeray',
#        'Steve Jackson', 'Marcus'], dtype=object)

# %%
cast[cast.name=='Sidney Poitier']['character'].nunique()
# Out:
# 41

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast.name=='Judi Dench']['character']
# Out:
# 2703455                        Nora Doel
# 2703456                      Mrs. Beaver
# 2703457                          Titania
# 2703458       Eleanor Lavish, a novelist
# 2703459                            Sally
# 2703460                       Miss Lilly
# 2703461                                M
# 2703462                   Armande Voizin
# 2703463                   Laura Davidson
# 2703464                                M
# 2703465                         Narrator
# 2703466                             Wife
# 2703467                                M
# 2703468                           Hecuba
# 2703469                           Joanne
# 2703470            Mistress Nell Quickly
# 2703471                     Mrs. Caloway
# 2703472                     Iris Murdoch
# 2703473                     Annie Hoover
# 2703474                         Margaret
# 2703475                     Mrs. Fairfax
# 2703476                          Paulina
# 2703477                           Ursula
# ...

# %%
cast[cast.name=='Judi Dench']['character'].nunique()
# Out:
# 46

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast.name=='Cary Grant')&(cast.year==1940)&(cast.n==2.0)]
# Out:
#                    title  year        name   type character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor      Nick  2.0

# %%
len(cast[(cast.name=='Cary Grant')&(cast.year==1940)&(cast.n==2.0)])
# Out:
# 1

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast.name=='Cary Grant')&(cast.year==1940)].sort_values('year')
# Out:
#                           title  year        name   type           character  \
# 840353          His Girl Friday  1940  Cary Grant  actor        Walter Burns
# 840371         My Favorite Wife  1940  Cary Grant  actor                Nick
# 840397  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard
# 840399   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven
#
#           n
# 840353  1.0
# 840371  2.0
# 840397  1.0
# 840399  1.0

# %%
cast[(cast.name=='Cary Grant')&(cast.year==1940)].sort_values('year')['character']
# Out:
# 840353          Walter Burns
# 840371                  Nick
# 840397           Matt Howard
# 840399    C. K. Dexter Haven
# Name: character, dtype: object

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[cast.year==1950].sort_values('character')['character'].unique()
# Out:
# array([' Durango Kid', ' Priest', "'45 Jones", ..., 'novillero',
#        'von Aster', 'von Stoffel'], dtype=object)

# %%
cast[cast.year==1950].sort_values('character')['character'].nunique()
# Out:
# 15007

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
cast[(cast.type=='actress')&(cast.year==1950)]['character'].unique()
# Out:
# array(['Apache Dancers', 'Model', 'Carriage Woman', ...,
#        'Do?a Blanquita Z??iga de Vallarta', 'May Takebayashi',
#        'Summer Camp Manager'], dtype=object)

# %%
cast[(cast.type=='actress')&(cast.year==1950)]['character'].nunique()
# Out:
# 4052

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast.n==1)&(cast.year<=1980)]['character'].nunique()
# Out:
# 51200

# %%
cast[(cast.n==1)&(cast.year<=1980)]
# Out:
#                                                      title  year  \
# 277                                           En glad gutt  1932
# 282                                      En herre med bart  1942
# 1026                                 Batman Fights Dracula  1967
# 1027                                 Batman Fights Dracula  1967
# 1031                                           Mighty Rock  1969
# 1121                              Ar Daijero, Rom agar var  1975
# 1126                                     Didi mtsvane veli  1967
# 1131                                             Kvarkvare  1978
# 1139                                    Pirveli mertskhali  1975
# 1142                             Sinatle chvens panjrebshi  1969
# 1147                                       Tsimbireli papa  1974
# 1154                                      Glakhis naambobi  1961
# 1221                                         Il pap'occhio  1980
# ...

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast[(cast.n!=1)&(cast.year<=1980)]['character'].nunique()
# Out:
# 558711

# %%
cast[(cast.n!=1)&(cast.year<=1980)].head()
# Out:
#                                        title  year                   name  \
# 20                            Natas es Satan  1977  Ramon 'Cartucho' Pena
# 32                              Los tarantos  1963             'El Guisa'
# 34                              Los tarantos  1963              'El Viti'
# 41  Been Down So Long It Looks Like Up to Me  1971         Murray the 'K'
# 42                    I Wanna Hold Your Hand  1978         Murray the 'K'
#
#      type         character     n
# 20  actor  Nigth Club Owner   NaN
# 32  actor           Bailaor  25.0
# 34  actor           Cantaor  20.0
# 41  actor           Himself   NaN
# 42  actor           Himself  48.0

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
no_rank=cast[(cast.year<=1980)].fillna(0)

# %%
no_rank[(no_rank.n==0)].sort_values('character')['character'].unique()
# Out:
# array([' Alamo defender', ' Avukat', ' Brawler', ..., 'zpevacka Virzinie',
#        'zweiter Professor', 'zyat Novosolyova'], dtype=object)

# %%
no_rank[(no_rank.n==0)].sort_values('character')['character'].nunique()
# Out:
# 186116
